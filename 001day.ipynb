# %% [markdown]
# <a href="https://colab.research.google.com/github/zixusir/calob/blob/master/001day.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 开始学习python
# 1. 从helloworld 开始

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # 2. 已经和世界打过了招呼，再画个画吧

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.subplot(111)

t = np.arange(0.0, 5.0,0.01)
s = np.cos(2 * np.pi * t)
line, =plt.plot(t, s, lw = 2)

plt.annotate('local max', xy = (2, 1), xytext = (3, 1.5), 
             arrowprops= dict(facecolor = 'black', shrink = 0.05))
plt.ylim(-2, 2)
plt.show()

# %% [markdown]
# # 3. 不错，再画一个心

# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0,2*np.pi, 0.1)
x = 16*np.sin(t)**3
y = 13*np.cos(t)-5*np.cos(2*t)-2*np.cos(3*t)-np.cos(4*t)
plt.plot(x,y,color = 'red')
plt.show()
